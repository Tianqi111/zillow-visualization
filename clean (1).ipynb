# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: numpy>=1.16 in /opt/anaconda3/lib/python3.9/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %%
#import libraries
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
house = pd.read_csv('./' + 'house50.csv')

# %%
house.head(5)
# Out:
#    Unnamed: 0                   zpid                     id         lotId  \
# 0           0   37.805623--122.27508   37.805623--122.27508  1.001487e+09
# 1           1  37.828877--122.265456  37.828877--122.265456  2.329248e+09
# 2           2  37.791842--122.420288  37.791842--122.420288  2.082886e+09
# 3           3             2067470365             2067470365           NaN
# 4           4             2067470396             2067470396           NaN
#
#                                               imgSrc hasImage statusType  \
# 0  https://photos.zillowstatic.com/fp/0a79a60e6ff...     True   FOR_RENT
# 1  https://photos.zillowstatic.com/fp/1ac29ea29ce...     True   FOR_RENT
# 2  https://photos.zillowstatic.com/fp/5f52a52b7d2...     True   FOR_RENT
# 3  https://photos.zillowstatic.com/fp/89e4e4abc7f...     True   FOR_RENT
# 4  https://photos.zillowstatic.com/fp/94617e1465b...     True   FOR_RENT
#
#            statusText                                          detailUrl  \
# 0      Domain Oakland               /b/domain-oakland-oakland-ca-5XjVPv/
# 1   MacArthur Commons            /b/macarthur-commons-oakland-ca-BG4Hxg/
# 2            For Rent     /b/1656-sacramento-st-san-francisco-ca-9NKFjJ/
# 3  Apartment for rent  https://www.zillow.com/homedetails/1614-Willow...
# 4  Apartment for rent  https://www.zillow.com/homedetails/270-Capitol...
#
#                                              latLong  ...    pgapt     sgapt  \
# 0   {'latitude': 37.805623, 'longitude': -122.27508}  ...      NaN       NaN
# 1  {'latitude': 37.828877, 'longitude': -122.265456}  ...      NaN       NaN
# 2  {'latitude': 37.791842, 'longitude': -122.420288}  ...      NaN       NaN
# 3    {'latitude': 37.770107, 'longitude': -122.2478}  ...  ForRent  For Rent
# 4  {'latitude': 37.712755, 'longitude': -122.458788}  ...  ForRent  For Rent
#
#    zestimate shouldShowZestimateAsPrice hasVideo isHomeRec  \
# 0        NaN                        NaN      NaN       NaN
# 1        NaN                        NaN      NaN       NaN
# 2        NaN                        NaN      NaN       NaN
# 3        NaN                      False    False     False
# 4        NaN                      False    False     False
#
#   hasAdditionalAttributions availabilityDate streetViewMetadataURL  \
# 0                       NaN              NaN                   NaN
# 1                       NaN              NaN                   NaN
# 2                       NaN              NaN                   NaN
# 3                     False              NaN                   NaN
# 4                     False              NaN                   NaN
#
#    streetViewURL
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#
# [5 rows x 48 columns]

# %%
#clean the data, drop useless columns
house1 = house[['unformattedPrice', 'address', 'addressStreet', 'addressCity', 'beds', 'baths', 'area', ]]
house1.head()
# Out:
#    unformattedPrice                                      address  \
# 0               NaN               1389 Jefferson St, Oakland, CA
# 1               NaN                     540 39th St, Oakland, CA
# 2               NaN        1656 Sacramento St, San Francisco, CA
# 3            2400.0            1614 Willow St, Alameda, CA 94501
# 4            3000.0  270 Capitol Ave #3, San Francisco, CA 94112
#
#               addressStreet    addressCity  beds  baths   area
# 0  1389 Jefferson St # C209        Oakland   NaN    NaN    NaN
# 1      540 39th St # A2-307        Oakland   NaN    NaN    NaN
# 2    1656 Sacramento St # 4  San Francisco   NaN    NaN    NaN
# 3            1614 Willow St        Alameda   1.0    1.0    NaN
# 4        270 Capitol Ave #3  San Francisco   2.0    2.0  900.0

# %%
#rename columns
house1.rename(columns={'unformattedPrice': 'Price'}, inplace=True)

# %%
#check if there are null 
house1.isnull().any()
# Out:
# unformattedPrice     True
# address             False
# addressStreet       False
# addressCity         False
# beds                 True
# baths                True
# area                 True
# dtype: bool

# %%
#sum null
pd.isnull(house1).sum()
# Out:
# unformattedPrice    172
# address               0
# addressStreet         0
# addressCity           0
# beds                172
# baths               175
# area                404
# dtype: int64

# %%
#clean null
house2 = house1.dropna(how='any', axis='rows')
house2.head()
# Out:
#    unformattedPrice                                      address  \
# 4            3000.0  270 Capitol Ave #3, San Francisco, CA 94112
# 5            2300.0  42 Grafton Ave #42, San Francisco, CA 94112
# 6            1950.0     (undisclosed Address), Alameda, CA 94501
# 7            2595.0    281 Juana Ave #204, San Leandro, CA 94577
# 8            2311.0  1411 Alice St #KQGEKNY6U, Oakland, CA 94612
#
#               addressStreet    addressCity  beds  baths    area
# 4        270 Capitol Ave #3  San Francisco   2.0    2.0   900.0
# 5        42 Grafton Ave #42  San Francisco   2.0    1.0   550.0
# 6     (undisclosed Address)        Alameda   1.0    1.0   600.0
# 7        281 Juana Ave #204    San Leandro   2.0    2.0  1200.0
# 8  1411 Alice St #KQGEKNY6U        Oakland   1.0    1.0   604.0

# %%
#check if clean well
pd.isnull(house2).sum()
# Out:
# unformattedPrice    0
# address             0
# addressStreet       0
# addressCity         0
# beds                0
# baths               0
# area                0
# dtype: int64

# %%
#check index
house2.index
# Out:
# Int64Index([  4,   5,   6,   7,   8,  13,  14,  19,  20,  26,
#             ...
#             987, 988, 989, 990, 991, 992, 994, 995, 996, 999],
#            dtype='int64', length=595)

# %%
#reset index
data = house2.reset_index(drop=True)

# %%
data.head()
# Out:
#    unformattedPrice                                      address  \
# 0            3000.0  270 Capitol Ave #3, San Francisco, CA 94112
# 1            2300.0  42 Grafton Ave #42, San Francisco, CA 94112
# 2            1950.0     (undisclosed Address), Alameda, CA 94501
# 3            2595.0    281 Juana Ave #204, San Leandro, CA 94577
# 4            2311.0  1411 Alice St #KQGEKNY6U, Oakland, CA 94612
#
#               addressStreet    addressCity  beds  baths    area
# 0        270 Capitol Ave #3  San Francisco   2.0    2.0   900.0
# 1        42 Grafton Ave #42  San Francisco   2.0    1.0   550.0
# 2     (undisclosed Address)        Alameda   1.0    1.0   600.0
# 3        281 Juana Ave #204    San Leandro   2.0    2.0  1200.0
# 4  1411 Alice St #KQGEKNY6U        Oakland   1.0    1.0   604.0

# %%
data.tail()
# Out:
#      unformattedPrice                                            address  \
# 590            3000.0  475 Arlington St #ROANOKE, San Francisco, CA 9...
# 591            2650.0    132 Clinton Park APT 3, San Francisco, CA 94103
# 592            2745.0           369 Staples Ave, San Francisco, CA 94112
# 593            2350.0                   2848 23rd Ave, Oakland, CA 94606
# 594            2480.0          601 Van Ness Ave, San Francisco, CA 94102
#
#                  addressStreet    addressCity  beds  baths    area
# 590  475 Arlington St #ROANOKE  San Francisco   2.0    1.0  1050.0
# 591     132 Clinton Park APT 3  San Francisco   2.0    1.0   750.0
# 592            369 Staples Ave  San Francisco   2.0    1.0   550.0
# 593              2848 23rd Ave        Oakland   2.0    1.0  1040.0
# 594           601 Van Ness Ave  San Francisco   1.0    1.0   694.0

# %%
#following steps to know the structure of data
data.size
# Out:
# 4165

# %%
data.shape
# Out:
# (595, 7)

# %%
data.columns
# Out:
# Index(['unformattedPrice', 'address', 'addressStreet', 'addressCity', 'beds',
#        'baths', 'area'],
#       dtype='object')

# %%
data.dtypes
# Out:
# unformattedPrice    float64
# address              object
# addressStreet        object
# addressCity          object
# beds                float64
# baths               float64
# area                float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 595 entries, 0 to 594
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   unformattedPrice  595 non-null    float64
#  1   address           595 non-null    object
#  2   addressStreet     595 non-null    object
#  3   addressCity       595 non-null    object
#  4   beds              595 non-null    float64
#  5   baths             595 non-null    float64
#  6   area              595 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 32.7+ KB

# %%
price_per_area = data["unformattedPrice"]/data["area"]
data.insert(7, 'Price Per Area', price_per_area)
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/7d/26xjnnps5_5b17xfxzmcg7v40000gn/T/ipykernel_29109/3286106374.py in <module>
#       1 price_per_area = data["unformattedPrice"]/data["area"]
# ----> 2 data.insert(7, 'Price Per Area', price_per_area)
#       3 data
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
#    4413             # Should this be a different kind of error??
# -> 4414             raise ValueError(f"cannot insert {column}, already exists")
#    4415         if not isinstance(loc, int):
#    4416             raise TypeError("loc must be int")
#
# ValueError: cannot insert Price Per Area, already exists

# %%
data.describe()
# Out:
#        unformattedPrice   beds  baths      area  Price Per Area
# count            595.00 595.00 595.00    595.00          595.00
# mean           2,443.34   1.53   1.17    896.73            3.30
# std              407.83   0.93   1.19    978.22            1.11
# min            1,000.00   1.00   0.00    110.00            0.12
# 25%            2,165.00   1.00   1.00    638.50            2.64
# 50%            2,495.00   1.00   1.00    750.00            3.16
# 75%            2,800.00   2.00   1.00    900.00            3.92
# max            3,000.00  18.00  18.00 16,809.00           11.36

# %%
data.groupby("addressCity").mean()
# Out:
#                unformattedPrice  beds  baths     area  Price Per Area
# addressCity
# Alameda                2,408.26  1.57   1.00 1,009.26            2.88
# Berkeley               2,297.50  2.00   1.00   775.00            2.97
# Daly City              2,545.83  1.67   1.17   800.50            3.53
# Emeryville             2,383.11  1.44   1.04   775.59            3.19
# Oakland                2,321.63  1.77   1.24 1,008.25            2.84
# San Francisco          2,587.65  1.30   1.04   760.64            3.85
# San Leandro            2,129.46  1.38   3.31 1,526.38            2.46

# %%
pd.options.display.float_format = '{:,.2f}'.format
data.groupby("addressCity").mean()
# Out:
#                unformattedPrice  beds  baths     area  Price Per Area
# addressCity
# Alameda                2,408.26  1.57   1.00 1,009.26            2.88
# Berkeley               2,297.50  2.00   1.00   775.00            2.97
# Daly City              2,545.83  1.67   1.17   800.50            3.53
# Emeryville             2,383.11  1.44   1.04   775.59            3.19
# Oakland                2,321.63  1.77   1.24 1,008.25            2.84
# San Francisco          2,587.65  1.30   1.04   760.64            3.85
# San Leandro            2,129.46  1.38   3.31 1,526.38            2.46

# %%
data.groupby("addressCity").count()
# Out:
#                unformattedPrice  address  addressStreet  beds  baths  area  \
# addressCity
# Alameda                      23       23             23    23     23    23
# Berkeley                      2        2              2     2      2     2
# Daly City                     6        6              6     6      6     6
# Emeryville                   27       27             27    27     27    27
# Oakland                     261      261            261   261    261   261
# San Francisco               263      263            263   263    263   263
# San Leandro                  13       13             13    13     13    13
#
#                Price Per Area
# addressCity
# Alameda                    23
# Berkeley                    2
# Daly City                   6
# Emeryville                 27
# Oakland                   261
# San Francisco             263
# San Leandro                13

# %%
from selenium import webdriver
import time

# %%
import chromedriver_autoinstaller
chromedriver_autoinstaller.install()  
browser = webdriver.Chrome()

# %%
all_addresses=data["address"]
all_prices=data["unformattedPrice"]
all_links=data["Price Per Area"]

# %%
for n in range(len(all_links)):
    # Substitute your own Google Form URL here 👇
    browser.get("https://docs.google.com/forms/d/e/1FAIpQLScEm7SDwSYvZgtLB9MNkyb6OKp3eJcQFTZxtWA-LtdIwjkD-Q/viewform?usp=sf_link")

    time.sleep(2)
    address = browser.find_element_by_xpath(
        '//*[@id="mG61Hd"]/div[2]/div/div[2]/div[1]/div/div/div[2]/div/div[1]/div/div[1]/input')
    price = browser.find_element_by_xpath(
        '//*[@id="mG61Hd"]/div[2]/div/div[2]/div[2]/div/div/div[2]/div/div[1]/div/div[1]/input')
    link = browser.find_element_by_xpath(
        '//*[@id="mG61Hd"]/div[2]/div/div[2]/div[3]/div/div/div[2]/div/div[1]/div/div[1]/input')
    submit_button = browser.find_element_by_xpath('//*[@id="mG61Hd"]/div[2]/div/div[3]/div[1]/div[1]/div/span/span')

    address.send_keys(all_addresses[n])
    price.send_keys(all_prices[n])
    link.send_keys(all_links[n])
    submit_button.click()
# Out:
# ---------------------------------------------------------------------------
# UnexpectedAlertPresentException           Traceback (most recent call last)
# /var/folders/7d/26xjnnps5_5b17xfxzmcg7v40000gn/T/ipykernel_29109/2250127761.py in <module>
#       1 for n in range(len(all_links)):
#       2     # Substitute your own Google Form URL here 👇
# ----> 3     browser.get("https://docs.google.com/forms/d/e/1FAIpQLScEm7SDwSYvZgtLB9MNkyb6OKp3eJcQFTZxtWA-LtdIwjkD-Q/viewform?usp=sf_link")
#       4
#       5     time.sleep(2)
#
# /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     434         Loads a web page in the current browser session.
#     435         """
# --> 436         self.execute(Command.GET, {'url': url})
#     437
#     438     @property
#
# /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# /opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     244             elif 'alert' in value:
#     245                 alert_text = value['alert'].get('text')
# --> 246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
#     247         raise exception_class(message, screen, stacktrace)
#     248
#
# UnexpectedAlertPresentException: Alert Text: {Alert text :
# Message: unexpected alert open: {Alert text : }
#   (Session info: chrome=96.0.4664.55)
# Stacktrace:
# 0   chromedriver                        0x000000010260fde9 __gxx_personality_v0 + 587625
# 1   chromedriver                        0x000000010259a433 __gxx_personality_v0 + 105907
# 2   chromedriver                        0x0000000102155578 chromedriver + 173432
# 3   chromedriver                        0x00000001021bb3a9 chromedriver + 590761
# 4   chromedriver                        0x00000001021a8b53 chromedriver + 514899
# 5   chromedriver                        0x000000010217e20e chromedriver + 340494
# 6   chromedriver                        0x000000010217f485 chromedriver + 345221
# 7   chromedriver                        0x00000001025cb6db __gxx_personality_v0 + 307291
# 8   chromedriver                        0x00000001025e25cf __gxx_personality_v0 + 401231
# 9   chromedriver                        0x00000001025e87ab __gxx_personality_v0 + 426283
# 10  chromedriver                        0x00000001025e393a __gxx_personality_v0 + 406202
# 11  chromedriver                        0x00000001025bfd81 __gxx_personality_v0 + 259841
# 12  chromedriver                        0x00000001025ffc78 __gxx_personality_v0 + 521720
# 13  chromedriver                        0x00000001025ffe01 __gxx_personality_v0 + 522113
# 14  chromedriver                        0x0000000102617268 __gxx_personality_v0 + 617448
# 15  libsystem_pthread.dylib             0x00007ff8144b9514 _pthread_start + 125
# 16  libsystem_pthread.dylib             0x00007ff8144b502f thread_start + 15
